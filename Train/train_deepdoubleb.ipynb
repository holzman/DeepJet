# %%
import sys
import os
copypath = ['../modules', 
            '../Train', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python27.zip', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/plat-linux2', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-tk', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-old', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-dynload', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg']
for p in reversed(copypath):
    sys.path.insert(0, p)
print sys.path
os.environ['KERAS_BACKEND'] = 'tensorflow'
os.environ['DEEPJET'] = '../../DeepJet'
#os.environ['LD_LIBRARY_PATH'] = '../modules:%s'%os.environ['LD_LIBRARY_PATH']
#os.environ['PATH'] = '../scripts:%s'%os.environ['PATH']
#os.environ['CONDA_PREFIX'] = '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu'
#os.environ['LD_PRELOAD'] = '%s/lib/libmkl_core.so:%s/lib/libmkl_sequential.so'%(os.environ['CONDA_PREFIX'],os.environ['CONDA_PREFIX'])
import keras
keras.backend.set_image_data_format('channels_first')
# Out:
# ['../modules', '../Train', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python27.zip', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/plat-linux2', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-tk', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-old', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-dynload', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg', '', '/opt/conda/envs/python2/lib/python27.zip', '/opt/conda/envs/python2/lib/python2.7', '/opt/conda/envs/python2/lib/python2.7/plat-linux2', '/opt/conda/envs/python2/lib/python2.7/lib-tk', '/opt/conda/envs/python2/lib/python2.7/lib-old', '/opt/conda/envs/python2/lib/python2.7/lib-dynload', '/opt/conda/envs/python2/lib/python2.7/site-packages', '/opt/conda/envs/python2/lib/python2.7/site-packages/Mako-1.0.7-py2.7.egg', '/opt/conda/envs/python2/lib/python2.7/site-packages/cycler-0.10.0-py2.7.egg', '/opt/conda/envs/python2/lib/python2.7/site-packages/IPython/extensions', '/home/jovyan/.ipython']
# Using TensorFlow backend.

# %%
class MyClass:
    """A simple example class"""
    def __init__(self):
        self.inputDataCollection = ''
        self.outputDir = ''

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

from training_base import training_base
from Losses import loss_NLL
import sys

args = MyClass()
args.inputDataCollection = '/inputdata/BumbleB/convert_deepDoubleB_init_train_val/dataCollection.dc'
args.outputDir = 'train_Resnet_sv_deepnew_3layers/'

#also does all the parsing
train=training_base(testrun=False,args=args)


if not train.modelSet():
    #from DeepJet_models_ResNet import resnet_model_doubleb_sv
    from DeepJet_models_ResNet import deep_model_doubleb_sv

    #train.setModel(resnet_model_doubleb_sv)
    train.setModel(deep_model_doubleb_sv)
    
    train.compileModel(learningrate=0.0001,
                       loss=['categorical_crossentropy'],
                       metrics=['accuracy'])
    

model,history,callbacks = train.trainModel(nepochs=100, 
                                 batchsize=1024, 
                                 stop_patience=10, 
                                 lr_factor=0.5, 
                                 lr_patience=10, 
                                 lr_epsilon=0.0001, 
                                 lr_cooldown=2, 
                                 lr_minimum=0.0001, 
                                 maxqsize=100)
# Out:
# [[1, 27], [5, 14]]
# (?, 1, 27)
# (?, 5, 14)
# (?, ?)
# (?, ?)
# (?, 2)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 1, 27)         0
# ____________________________________________________________________________________________________
# input_2 (InputLayer)             (None, 5, 14)         0
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 27)            0
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 70)            0
# ____________________________________________________________________________________________________
# concat (Concatenate)             (None, 97)            0
# ____________________________________________________________________________________________________
# fc1_relu (Dense)                 (None, 100)           9800
# ____________________________________________________________________________________________________
# fc1_dropout (Dropout)            (None, 100)           0
# ____________________________________________________________________________________________________
# fc2_relu (Dense)                 (None, 100)           10100
# ____________________________________________________________________________________________________
# fc2_dropout (Dropout)            (None, 100)           0
# ____________________________________________________________________________________________________
# fc3_relu (Dense)                 (None, 100)           10100
# ____________________________________________________________________________________________________
# fc3_dropout (Dropout)            (None, 100)           0
# ____________________________________________________________________________________________________
# softmax (Dense)                  (None, 2)             202
# ====================================================================================================
# Total params: 30,202.0
# Trainable params: 30,202.0
# Non-trainable params: 0.0
# ____________________________________________________________________________________________________
# None
# Epoch 1/100
# 15616/15617 [============================>.] - ETA: 0s - loss: 0.0886 - acc: 0.9796
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00000: val_loss improved from inf to 0.14901, saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_best_model.h5
# Epoch 00000: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 285s - loss: 0.0886 - acc: 0.9796 - val_loss: 0.1490 - val_acc: 0.9676
# Epoch 2/100
# 15615/15617 [============================>.] - ETA: 0s - loss: 0.1254 - acc: 0.9718
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00001: val_loss improved from 0.14901 to 0.14843, saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_best_model.h5
# Epoch 00001: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 283s - loss: 0.1254 - acc: 0.9718 - val_loss: 0.1484 - val_acc: 0.9676
# Epoch 3/100
# 15615/15617 [============================>.] - ETA: 0s - loss: 0.1261 - acc: 0.9718
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00002: val_loss did not improve
# Epoch 00002: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 279s - loss: 0.1261 - acc: 0.9718 - val_loss: 0.1485 - val_acc: 0.9671
# Epoch 4/100
# 15616/15617 [============================>.] - ETA: 0s - loss: 0.1261 - acc: 0.9717- E
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00003: val_loss did not improve
# Epoch 00003: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 281s - loss: 0.1261 - acc: 0.9717 - val_loss: 0.1490 - val_acc: 0.9672
# Epoch 5/100
# 15615/15617 [============================>.] - ETA: 0s - loss: 0.1258 - acc: 0.9718
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00004: val_loss improved from 0.14843 to 0.14449, saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_best_model.h5
# Epoch 00004: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 280s - loss: 0.1258 - acc: 0.9718 - val_loss: 0.1445 - val_acc: 0.9675
# Epoch 6/100
# 15616/15617 [============================>.] - ETA: 0s - loss: 0.1254 - acc: 0.9719
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00005: val_loss did not improve
# Epoch 00005: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 280s - loss: 0.1254 - acc: 0.9719 - val_loss: 0.1476 - val_acc: 0.9676
# Epoch 7/100
# 15615/15617 [============================>.] - ETA: 0s - loss: 0.1262 - acc: 0.9717
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00006: val_loss did not improve
# Epoch 00006: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 281s - loss: 0.1262 - acc: 0.9717 - val_loss: 0.1461 - val_acc: 0.9677
# Epoch 8/100
# 15615/15617 [============================>.] - ETA: 0s - loss: 0.1253 - acc: 0.9720
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00007: val_loss did not improve
# Epoch 00007: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 280s - loss: 0.1253 - acc: 0.9720 - val_loss: 0.1467 - val_acc: 0.9678
# Epoch 9/100
# 15614/15617 [============================>.] - ETA: 0s - loss: 0.1262 - acc: 0.9717
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00008: val_loss did not improve
# Epoch 00008: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 279s - loss: 0.1262 - acc: 0.9717 - val_loss: 0.1462 - val_acc: 0.9674
# Epoch 10/100
# 15614/15617 [============================>.] - ETA: 0s - loss: 0.1256 - acc: 0.9719
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00009: val_loss did not improve
# Epoch 00009: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
# Epoch 00009: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_epoch09.h5
#
# ***callbacks end***
# 15617/15617 [==============================] - 284s - loss: 0.1256 - acc: 0.9719 - val_loss: 0.1458 - val_acc: 0.9677
# Epoch 11/100
# 15614/15617 [============================>.] - ETA: 0s - loss: 0.1260 - acc: 0.9717
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00010: val_loss did not improve
# Epoch 00010: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 283s - loss: 0.1260 - acc: 0.9718 - val_loss: 0.1474 - val_acc: 0.9674
# Epoch 12/100
# 15616/15617 [============================>.] - ETA: 0s - loss: 0.1261 - acc: 0.9717
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00011: val_loss did not improve
# Epoch 00011: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 278s - loss: 0.1261 - acc: 0.9717 - val_loss: 0.1447 - val_acc: 0.9678
# Epoch 13/100
# 15615/15617 [============================>.] - ETA: 0s - loss: 0.1257 - acc: 0.9719
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00012: val_loss did not improve
# Epoch 00012: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 278s - loss: 0.1257 - acc: 0.9719 - val_loss: 0.1479 - val_acc: 0.9669
# Epoch 14/100
# 15613/15617 [============================>.] - ETA: 0s - loss: 0.1260 - acc: 0.9718
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00013: val_loss did not improve
# Epoch 00013: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 190s - loss: 0.1259 - acc: 0.9718 - val_loss: 0.1447 - val_acc: 0.9682
# Epoch 15/100
# 15616/15617 [============================>.] - ETA: 0s - loss: 0.1254 - acc: 0.9720
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00014: val_loss did not improve
# Epoch 00014: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 121s - loss: 0.1254 - acc: 0.9720 - val_loss: 0.1468 - val_acc: 0.9673
# Epoch 16/100
# 15616/15617 [============================>.] - ETA: 0s - loss: 0.1259 - acc: 0.9718
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00015: val_loss improved from 0.14449 to 0.14409, saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_best_model.h5
# Epoch 00015: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 122s - loss: 0.1259 - acc: 0.9718 - val_loss: 0.1441 - val_acc: 0.9681
# Epoch 17/100
# 15614/15617 [============================>.] - ETA: 0s - loss: 0.1266 - acc: 0.9716
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers/losses.log
# Epoch 00016: val_loss did not improve
# Epoch 00016: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv_deepnew_3layers//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 15617/15617 [==============================] - 121s - loss: 0.1266 - acc: 0.9716 - val_loss: 0.1490 - val_acc: 0.9677
# Epoch 18/100
#  8459/15617 [===============>..............] - ETA: 54s - loss: 0.1413 - acc: 0.9672

# %%
# !rm -r train_Resnet_sv_deepnew_3layers
# Out:
# rm: cannot remove ‘train_Resnet_sv_deepnew_3layers’: No such file or directory
