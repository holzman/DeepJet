# %%
import sys
import os
copypath = ['../modules', 
            '../Train', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python27.zip', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/plat-linux2', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-tk', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-old', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-dynload', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages', 
            '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg']
for p in reversed(copypath):
    sys.path.insert(0, p)
print sys.path
os.environ['KERAS_BACKEND'] = 'tensorflow'
os.environ['DEEPJET'] = '../../DeepJet'
#os.environ['LD_LIBRARY_PATH'] = '../modules:%s'%os.environ['LD_LIBRARY_PATH']
#os.environ['PATH'] = '../scripts:%s'%os.environ['PATH']
#os.environ['CONDA_PREFIX'] = '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu'
#os.environ['LD_PRELOAD'] = '%s/lib/libmkl_core.so:%s/lib/libmkl_sequential.so'%(os.environ['CONDA_PREFIX'],os.environ['CONDA_PREFIX'])
import keras
keras.backend.set_image_data_format('channels_first')
# Out:
# ['../modules', '../Train', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python27.zip', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/plat-linux2', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-tk', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-old', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/lib-dynload', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages', '/inputdata/BumbleB/jduarte/miniconda2/envs/deepjetLinux3_gpu/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg', '', '/opt/conda/envs/python2/lib/python27.zip', '/opt/conda/envs/python2/lib/python2.7', '/opt/conda/envs/python2/lib/python2.7/plat-linux2', '/opt/conda/envs/python2/lib/python2.7/lib-tk', '/opt/conda/envs/python2/lib/python2.7/lib-old', '/opt/conda/envs/python2/lib/python2.7/lib-dynload', '/opt/conda/envs/python2/lib/python2.7/site-packages', '/opt/conda/envs/python2/lib/python2.7/site-packages/Mako-1.0.7-py2.7.egg', '/opt/conda/envs/python2/lib/python2.7/site-packages/cycler-0.10.0-py2.7.egg', '/opt/conda/envs/python2/lib/python2.7/site-packages/IPython/extensions', '/home/jovyan/.ipython']
# Using TensorFlow backend.

# %%
class MyClass:
    """A simple example class"""
    def __init__(self):
        self.inputDataCollection = ''
        self.outputDir = ''

# %%
from training_base import training_base
from Losses import loss_NLL
import sys

args = MyClass()
args.inputDataCollection = '/inputdata/BumbleB/convert_deepDoubleB_init_train_val/dataCollection.dc'
args.outputDir = 'train_Resnet_sv/'

#also does all the parsing
train=training_base(testrun=False,args=args)


if not train.modelSet():
    from DeepJet_models_ResNet import resnet_model_doubleb_sv
    
    train.setModel(resnet_model_doubleb_sv)
    
    train.compileModel(learningrate=0.0004,
                       loss=['categorical_crossentropy'],
                       metrics=['accuracy'])
    

model,history,callbacks = train.trainModel(nepochs=10, 
                                 batchsize=4096, 
                                 stop_patience=10, 
                                 lr_factor=0.5, 
                                 lr_patience=10, 
                                 lr_epsilon=0.0001, 
                                 lr_cooldown=2, 
                                 lr_minimum=0.0001, 
                                 maxqsize=100)
# Out:
# setGPU: Setting GPU to: 0
# [[1, 27], [5, 14]]
# (?, 1, 27)
# (?, 5, 14)
# (?, ?)
# (?, 2)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 5, 14)         0
# ____________________________________________________________________________________________________
# sv_bn_data (BatchNormalization)  (None, 5, 14)         42
# ____________________________________________________________________________________________________
# sv_conv0 (Conv1D)                (None, 5, 32)         1344
# ____________________________________________________________________________________________________
# sv_stage1_unit1_bn1 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage1_unit1_relu1 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage1_unit1_conv1 (Conv1D)   (None, 5, 32)         3072
# ____________________________________________________________________________________________________
# sv_stage1_unit1_bn2 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage1_unit1_relu2 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage1_unit1_conv2 (Conv1D)   (None, 5, 32)         3072
# ____________________________________________________________________________________________________
# sv_stage1_unit1_shortcut (Conv1D (None, 5, 32)         1024
# ____________________________________________________________________________________________________
# add_1 (Add)                      [(None, 5, 32), (None 0
# ____________________________________________________________________________________________________
# sv_stage1_unit2_bn1 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage1_unit2_relu1 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage1_unit2_conv1 (Conv1D)   (None, 5, 32)         3072
# ____________________________________________________________________________________________________
# sv_stage1_unit2_bn2 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage1_unit2_relu2 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage1_unit2_conv2 (Conv1D)   (None, 5, 32)         3072
# ____________________________________________________________________________________________________
# add_2 (Add)                      [(None, 5, 32), (None 0
# ____________________________________________________________________________________________________
# sv_stage1_unit3_bn1 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage1_unit3_relu1 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage1_unit3_conv1 (Conv1D)   (None, 5, 32)         3072
# ____________________________________________________________________________________________________
# sv_stage1_unit3_bn2 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage1_unit3_relu2 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage1_unit3_conv2 (Conv1D)   (None, 5, 32)         3072
# ____________________________________________________________________________________________________
# add_3 (Add)                      [(None, 5, 32), (None 0
# ____________________________________________________________________________________________________
# sv_stage2_unit1_bn1 (BatchNormal (None, 5, 32)         128
# ____________________________________________________________________________________________________
# sv_stage2_unit1_relu1 (Activatio (None, 5, 32)         0
# ____________________________________________________________________________________________________
# sv_stage2_unit1_conv1 (Conv1D)   (None, 3, 64)         6144
# ____________________________________________________________________________________________________
# sv_stage2_unit1_bn2 (BatchNormal (None, 3, 64)         256
# ____________________________________________________________________________________________________
# sv_stage2_unit1_relu2 (Activatio (None, 3, 64)         0
# ____________________________________________________________________________________________________
# sv_stage2_unit1_conv2 (Conv1D)   (None, 3, 64)         12288
# ____________________________________________________________________________________________________
# sv_stage2_unit1_shortcut (Conv1D (None, 3, 64)         2048
# ____________________________________________________________________________________________________
# add_4 (Add)                      [(None, 3, 64), (None 0
# ____________________________________________________________________________________________________
# sv_stage2_unit2_bn1 (BatchNormal (None, 3, 64)         256
# ____________________________________________________________________________________________________
# sv_stage2_unit2_relu1 (Activatio (None, 3, 64)         0
# ____________________________________________________________________________________________________
# sv_stage2_unit2_conv1 (Conv1D)   (None, 3, 64)         12288
# ____________________________________________________________________________________________________
# sv_stage2_unit2_bn2 (BatchNormal (None, 3, 64)         256
# ____________________________________________________________________________________________________
# sv_stage2_unit2_relu2 (Activatio (None, 3, 64)         0
# ____________________________________________________________________________________________________
# sv_stage2_unit2_conv2 (Conv1D)   (None, 3, 64)         12288
# ____________________________________________________________________________________________________
# add_5 (Add)                      [(None, 3, 64), (None 0
# ____________________________________________________________________________________________________
# sv_stage2_unit3_bn1 (BatchNormal (None, 3, 64)         256
# ____________________________________________________________________________________________________
# sv_stage2_unit3_relu1 (Activatio (None, 3, 64)         0
# ____________________________________________________________________________________________________
# sv_stage2_unit3_conv1 (Conv1D)   (None, 3, 64)         12288
# ____________________________________________________________________________________________________
# sv_stage2_unit3_bn2 (BatchNormal (None, 3, 64)         256
# ____________________________________________________________________________________________________
# sv_stage2_unit3_relu2 (Activatio (None, 3, 64)         0
# ____________________________________________________________________________________________________
# sv_stage2_unit3_conv2 (Conv1D)   (None, 3, 64)         12288
# ____________________________________________________________________________________________________
# add_6 (Add)                      [(None, 3, 64), (None 0
# ____________________________________________________________________________________________________
# sv_bn1 (BatchNormalization)      (None, 3, 64)         256
# ____________________________________________________________________________________________________
# input_1 (InputLayer)             (None, 1, 27)         0
# ____________________________________________________________________________________________________
# sv_relu1 (Activation)            (None, 3, 64)         0
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 27)            0
# ____________________________________________________________________________________________________
# sv_pool (GlobalAveragePooling1D) (None, 64)            0
# ____________________________________________________________________________________________________
# concat (Concatenate)             (None, 91)            0
# ____________________________________________________________________________________________________
# fc1_relu (Dense)                 (None, 512)           47104
# ____________________________________________________________________________________________________
# fc1_dropout (Dropout)            (None, 512)           0
# ____________________________________________________________________________________________________
# softmax (Dense)                  (None, 2)             1026
# ====================================================================================================
# Total params: 141,036.0
# Trainable params: 139,792.0
# Non-trainable params: 1,244.0
# ____________________________________________________________________________________________________
# None
# Epoch 1/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.2082 - acc: 0.9793
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00000: val_loss improved from inf to 0.18066, saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_best_model.h5
# Epoch 00000: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 176s - loss: 0.2082 - acc: 0.9793 - val_loss: 0.1807 - val_acc: 0.9670
# Epoch 2/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1360 - acc: 0.9726
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00001: val_loss improved from 0.18066 to 0.14590, saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_best_model.h5
# Epoch 00001: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1360 - acc: 0.9726 - val_loss: 0.1459 - val_acc: 0.9668
# Epoch 3/10
# 3902/3904 [============================>.] - ETA: 0s - loss: 0.1253 - acc: 0.9725
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00002: val_loss did not improve
# Epoch 00002: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1253 - acc: 0.9726 - val_loss: 0.1492 - val_acc: 0.9665
# Epoch 4/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1259 - acc: 0.9725
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00003: val_loss did not improve
# Epoch 00003: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1259 - acc: 0.9725 - val_loss: 0.1524 - val_acc: 0.9656
# Epoch 5/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1257 - acc: 0.9725
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00004: val_loss did not improve
# Epoch 00004: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1257 - acc: 0.9725 - val_loss: 0.1512 - val_acc: 0.9659
# Epoch 6/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1263 - acc: 0.9723
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00005: val_loss did not improve
# Epoch 00005: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1263 - acc: 0.9723 - val_loss: 0.1472 - val_acc: 0.9669
# Epoch 7/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1256 - acc: 0.9725
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00006: val_loss did not improve
# Epoch 00006: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1256 - acc: 0.9725 - val_loss: 0.1460 - val_acc: 0.9674
# Epoch 8/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1258 - acc: 0.9725
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00007: val_loss did not improve
# Epoch 00007: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1258 - acc: 0.9725 - val_loss: 0.1497 - val_acc: 0.9663
# Epoch 9/10
# 3903/3904 [============================>.] - ETA: 0s - loss: 0.1256 - acc: 0.9725
# ***callbacks***
# saving losses to /home/jovyan/work/DeepJet/Train/train_Resnet_sv/losses.log
# Epoch 00008: val_loss did not improve
# Epoch 00008: saving model to /home/jovyan/work/DeepJet/Train/train_Resnet_sv//KERAS_check_model_last.h5
#
# ***callbacks end***
#
# 3904/3904 [==============================] - 171s - loss: 0.1256 - acc: 0.9725 - val_loss: 0.1510 - val_acc: 0.9661
# Epoch 10/10
# 3902/3904 [============================>.] - ETA: 0s - loss: 0.1258 - acc: 0.9725
